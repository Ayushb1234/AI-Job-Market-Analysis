# %%
#  dataset 2 work done to be here
# ------------------------------------

# !pip install pandas numpy matplotlib seaborn scikit-learn openpyxl
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
table1 = pd.read_csv(r"C:\Users\ka843\Coding\AI-Job-Market-Analysis\data\raw\Placement2\indian_student_placement_data.csv")

table2 = pd.read_csv(r"C:\Users\ka843\Coding\AI-Job-Market-Analysis\data\raw\Placement\placement_targets.csv")

table3 = pd.read_csv(r"C:\Users\ka843\Coding\AI-Job-Market-Analysis\data\raw\Placement\indian_engineering_student_placement.csv")

# %%
table1["student_id"] = range(1, len(table1) + 1)

# %%
table1.head()
# Out:
#                name                     email course      branch  \
# 0      Yasmin Yadav           ibrar@gmail.com   B.Sc       Civil
# 1      Ritvik Kalla  stuvansaxena@hotmail.com    BCA         EEE
# 2       Rasha Dewan       neysasule@yahoo.com  B.Com          IT
# 3  Indranil Sawhney  sekhonraghav@hotmail.com    BBA  Mechanical
# 4       Aarav Konda      kurianshray@bava.com    BCA          IT
#
#    graduation year    company           job role  salary (inr)   location  \
# 0             2020     Google      Web Developer        808813      Delhi
# 1             2022  Accenture   Support Engineer        309179  Bangalore
# 2             2023  Accenture  Software Engineer        711614  Hyderabad
# 3             2024        TCS         Consultant        717444     Mumbai
# 4             2023        IBM       Data Analyst       1171796  Hyderabad
#
#   placement date  student_id
# 0     2024-08-14           1
# 1     2025-02-05           2
# 2     2024-03-09           3
# ...

# %%
table2.head()
# Out:
#    student_id placement_status  salary_lpa
# 0           1           Placed       14.95
# 1           2           Placed       14.91
# 2           3           Placed       17.73
# 3           4           Placed       14.52
# 4           5           Placed       15.91

# %%
table3.head()
# Out:
#    Student_ID  gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 0           1    Male    ECE  8.74              74.0                75.0
# 1           2  Female    ECE  7.80              75.3                69.7
# 2           3  Female     IT  6.95              62.8                68.3
# 3           4    Male    ECE  7.46              57.9                51.4
# 4           5    Male     IT  6.86              61.3                73.5
#
#    backlogs  study_hours_per_day  attendance_percentage  projects_completed  \
# 0         0                  3.8                   71.1                   7
# 1         0                  6.3                   69.5                   5
# 2         0                  1.5                   62.5                   8
# 3         1                  4.7                   64.6                   6
# 4         2                  5.2                   75.9                   3
#
# ...

# %%
print(table1.columns)

print(table2.columns)

print(table3.columns)
# Out:
# Index(['name', 'email', 'course', 'branch', 'graduation year', 'company',
#        'job role', 'salary (inr)', 'location', 'placement date', 'student_id'],
#       dtype='str')
# Index(['student_id', 'placement_status', 'salary_lpa'], dtype='str')
# Index(['student_id', 'gender', 'branch', 'cgpa', 'tenth_percentage',
#        'twelfth_percentage', 'backlogs', 'study_hours_per_day',
#        'attendance_percentage', 'projects_completed', 'internships_completed',
#        'coding_skill_rating', 'communication_skill_rating',
#        'aptitude_skill_rating', 'hackathons_participated',
#        'certifications_count', 'sleep_hours', 'stress_level', 'part_time_job',
#        'family_income_level', 'city_tier', 'internet_access',
#        'extracurricular_involvement'],
#       dtype='str')

# %%
table1.columns = table1.columns.str.strip().str.lower()

table2.columns = table2.columns.str.strip().str.lower()

table3.columns = table3.columns.str.strip().str.lower()

# %%
print(table1.columns)

print(table2.columns)

print(table3.columns)
# Out:
# Index(['name', 'email', 'course', 'branch', 'graduation year', 'company',
#        'job role', 'salary (inr)', 'location', 'placement date', 'student_id'],
#       dtype='str')
# Index(['student_id', 'placement_status', 'salary_lpa'], dtype='str')
# Index(['student_id', 'gender', 'branch', 'cgpa', 'tenth_percentage',
#        'twelfth_percentage', 'backlogs', 'study_hours_per_day',
#        'attendance_percentage', 'projects_completed', 'internships_completed',
#        'coding_skill_rating', 'communication_skill_rating',
#        'aptitude_skill_rating', 'hackathons_participated',
#        'certifications_count', 'sleep_hours', 'stress_level', 'part_time_job',
#        'family_income_level', 'city_tier', 'internet_access',
#        'extracurricular_involvement'],
#       dtype='str')

# %%
merged_df = pd.merge(
    table3,
    table2,
    on="student_id",
    how="inner"
)

# %%
master_df = pd.merge(
    merged_df,
    table1,
    on="student_id",
    how="inner"
)

# %%
master_df.head()

master_df.shape
# Out:
# (1000, 35)

# %%
master_df.isnull().sum()
# Out:
# student_id                       0
# gender                           0
# branch_x                         0
# cgpa                             0
# tenth_percentage                 0
# twelfth_percentage               0
# backlogs                         0
# study_hours_per_day              0
# attendance_percentage            0
# projects_completed               0
# internships_completed            0
# coding_skill_rating              0
# communication_skill_rating       0
# aptitude_skill_rating            0
# hackathons_participated          0
# certifications_count             0
# sleep_hours                      0
# stress_level                     0
# part_time_job                    0
# family_income_level              0
# city_tier                        0
# internet_access                  0
# extracurricular_involvement    202
# placement_status                 0
# salary_lpa                       0
# name                             0
# email                            0
# ...

# %%
master_df.to_csv(
    r"C:\Users\ka843\Coding\AI-Job-Market-Analysis\data\processed\master_dataset_2.csv",
    index=False
)

# %%
data = pd.read_csv(r"C:\Users\ka843\Coding\AI-Job-Market-Analysis\data\processed\master_dataset_2.csv")
data.head()
# Out:
#    student_id  gender branch_x  cgpa  tenth_percentage  twelfth_percentage  \
# 0           1    Male      ECE  8.74              74.0                75.0
# 1           2  Female      ECE  7.80              75.3                69.7
# 2           3  Female       IT  6.95              62.8                68.3
# 3           4    Male      ECE  7.46              57.9                51.4
# 4           5    Male       IT  6.86              61.3                73.5
#
#    backlogs  study_hours_per_day  attendance_percentage  projects_completed  \
# 0         0                  3.8                   71.1                   7
# 1         0                  6.3                   69.5                   5
# 2         0                  1.5                   62.5                   8
# 3         1                  4.7                   64.6                   6
# 4         2                  5.2                   75.9                   3
#
# ...

# %%
data['gender'].value_counts()
# Out:
# gender
# Male      613
# Female    387
# Name: count, dtype: int64

# %%
data['branch_x'].value_counts()
# Out:
# branch_x
# CSE    301
# ECE    253
# IT     200
# ME     154
# CE      92
# Name: count, dtype: int64

# %%
data['part_time_job'].value_counts()
# Out:
# part_time_job
# No     821
# Yes    179
# Name: count, dtype: int64

# %%
data['family_income_level'].value_counts()
# Out:
# family_income_level
# Medium    505
# Low       292
# High      203
# Name: count, dtype: int64

# %%
data['city_tier'].value_counts()
# Out:
# city_tier
# Tier 2    385
# Tier 1    319
# Tier 3    296
# Name: count, dtype: int64

# %%
data['internet_access'].value_counts()
# Out:
# internet_access
# Yes    886
# No     114
# Name: count, dtype: int64

# %%
data['internet_access'] = data['internet_access'].map({'Yes': 1, 'No': 0})

# %%
data['gender'] = data['gender'].map({'Male': 1, 'Female': 0})
